# %%
# Competition: Loan Approval Prediction
# Link: https://www.kaggle.com/competitions/playground-series-s4e10
import kagglehub
import kagglehub.auth
import polars as pl
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline

matplotlib_inline.backend_inline.set_matplotlib_formats("svg")

# %%
loan_approval_train = kagglehub.competition_download(
    "playground-series-s4e10", path="train.csv"
)
loan_approval_train_data = pl.read_csv(loan_approval_train)
loan_approval_train_data.head()
# Out:
# shape: (5, 13)
# ┌─────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ id  ┆ person_age ┆ person_inc ┆ person_hom ┆ … ┆ loan_perce ┆ cb_person_ ┆ cb_person ┆ loan_stat │
# │ --- ┆ ---        ┆ ome        ┆ e_ownershi ┆   ┆ nt_income  ┆ default_on ┆ _cred_his ┆ us        │
# │ i64 ┆ i64        ┆ ---        ┆ p          ┆   ┆ ---        ┆ _file      ┆ t_length  ┆ ---       │
# │     ┆            ┆ i64        ┆ ---        ┆   ┆ f64        ┆ ---        ┆ ---       ┆ i64       │
# │     ┆            ┆            ┆ str        ┆   ┆            ┆ str        ┆ i64       ┆           │
# ╞═════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 0   ┆ 37         ┆ 35000      ┆ RENT       ┆ … ┆ 0.17       ┆ N          ┆ 14        ┆ 0         │
# │ 1   ┆ 22         ┆ 56000      ┆ OWN        ┆ … ┆ 0.07       ┆ N          ┆ 2         ┆ 0         │
# │ 2   ┆ 29         ┆ 28800      ┆ OWN        ┆ … ┆ 0.21       ┆ N          ┆ 10        ┆ 0         │
# │ 3   ┆ 30         ┆ 70000      ┆ RENT       ┆ … ┆ 0.17       ┆ N          ┆ 5         ┆ 0         │
# │ 4   ┆ 22         ┆ 60000      ┆ RENT       ┆ … ┆ 0.1        ┆ N          ┆ 3         ┆ 0         │
# └─────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
df_0 = loan_approval_train_data.filter(loan_status=0)
df_1 = loan_approval_train_data.filter(loan_status=1)
df_0 = df_0.sample(n=df_1.height, shuffle=True, seed=42)  # Balance the dataset
df = pl.concat([df_0, df_1])
df = df.drop("id")
features = df[:, :-1]
labels = df[:, -1]
print(features.shape, labels.shape)
df.head()
# Out:
# (16700, 11) (16700,)
# shape: (5, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ person_ag ┆ person_in ┆ person_ho ┆ person_em ┆ … ┆ loan_perc ┆ cb_person ┆ cb_person ┆ loan_sta │
# │ e         ┆ come      ┆ me_owners ┆ p_length  ┆   ┆ ent_incom ┆ _default_ ┆ _cred_his ┆ tus      │
# │ ---       ┆ ---       ┆ hip       ┆ ---       ┆   ┆ e         ┆ on_file   ┆ t_length  ┆ ---      │
# │ i64       ┆ i64       ┆ ---       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ i64      │
# │           ┆           ┆ str       ┆           ┆   ┆ f64       ┆ str       ┆ i64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 27        ┆ 42000     ┆ RENT      ┆ 3.0       ┆ … ┆ 0.07      ┆ N         ┆ 8         ┆ 0        │
# │ 23        ┆ 110000    ┆ MORTGAGE  ┆ 7.0       ┆ … ┆ 0.05      ┆ N         ┆ 4         ┆ 0        │
# │ 21        ┆ 42000     ┆ RENT      ┆ 5.0       ┆ … ┆ 0.14      ┆ N         ┆ 3         ┆ 0        │
# │ 30        ┆ 37000     ┆ RENT      ┆ 0.0       ┆ … ┆ 0.16      ┆ N         ┆ 10        ┆ 0        │
# │ 26        ┆ 51600     ┆ RENT      ┆ 0.0       ┆ … ┆ 0.03      ┆ N         ┆ 4         ┆ 0        │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
def clean(df: pl.DataFrame) -> pl.DataFrame:
    df = df.with_columns(
        loan_grade=16 - pl.col("loan_grade").str.to_integer(base=32),
        cb_person_default_on_file=pl.when(pl.col("cb_person_default_on_file") == "Y")
        .then(1)
        .otherwise(0),
    )
    df = df.to_dummies(["person_home_ownership", "loan_intent"])
    return df


data = clean(features).to_torch().float()
labels = labels.to_torch().long()
print(data.shape, data.min(), data.max())
print(labels.shape, labels.min(), labels.max())
# Out:
# torch.Size([16700, 19]) tensor(0.) tensor(948000.)
# torch.Size([16700]) tensor(0) tensor(1)

# %%
train_data, val_data, train_labels, val_labels = train_test_split(
    data, labels, test_size=0.2, random_state=42
)
val_data, test_data, val_labels, test_labels = train_test_split(
    val_data, val_labels, test_size=0.5, random_state=42
)
train_data = train_data / torch.max(train_data)
val_data = val_data / torch.max(val_data)
test_data = test_data / torch.max(test_data)

train_dataset = TensorDataset(train_data, train_labels)
val_dataset = TensorDataset(val_data, val_labels)
test_dataset = TensorDataset(test_data, test_labels)

batch_size = 32
train_loader = DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, drop_last=True
)
val_loader = DataLoader(val_dataset, batch_size=val_dataset.tensors[0].shape[0])
test_loader = DataLoader(test_dataset, batch_size=test_dataset.tensors[0].shape[0])

print(f"train_data: {train_dataset.tensors[0].dtype}")
print(f"train_labels: {train_dataset.tensors[1].dtype}")
print(f"val_data: {val_dataset.tensors[0].dtype}")
print(f"val_labels: {val_dataset.tensors[1].dtype}")
print(f"test_data: {test_dataset.tensors[0].dtype}")
print(f"test_labels: {test_dataset.tensors[1].dtype}")
# Out:
# train_data: torch.float32
# train_labels: torch.int64
# val_data: torch.float32
# val_labels: torch.int64
# test_data: torch.float32
# test_labels: torch.int64

# %%
print(f"Training data range {train_data.min()} - {train_data.max()}")
print(f"Val data range {val_data.min()} - {val_data.max()}")
print(f"Test data range {test_data.min()} - {test_data.max()}")
# Out:
# Training data range 0.0 - 1.0
# Val data range 0.0 - 1.0
# Test data range 0.0 - 1.0

# %%
class LoanApprovalModel(nn.Module):
    def __init__(self, input_dim: int):
        super().__init__()
        self.input = nn.Linear(input_dim, 128)
        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
        self.output = nn.Linear(16, 2)

    def forward(self, x):
        x = F.relu(self.input(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.output(x)
        return torch.log_softmax(x, dim=1)


def create_model(input_dim: int = 19) -> tuple:
    model = LoanApprovalModel(input_dim)
    loss_fn = nn.NLLLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    return model, loss_fn, optimizer

# %%
def train_model(epochs: int = 100, learning_rate: float = 0.001):
    model, loss_fn, optimizer = create_model(input_dim=train_data.shape[1])
    losses = torch.zeros(epochs, 2)
    train_accuracies = []
    val_accuracies = []

    for epoch in range(epochs):
        batch_losses = []
        batch_accuracies = []
        for X, y in train_loader:
            # forward pass
            y_hat = model(X)
            loss = loss_fn(y_hat, y)
            # backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # calculate accuracy
            batch_losses.append(loss.item())
            matches = (y_hat.argmax(dim=1) == y).float()
            batch_accuracies.append(100 * matches.mean().item())

        train_accuracy = np.mean(batch_accuracies)
        losses[epoch, 0] = np.mean(batch_losses)

        X, y = next(iter(val_loader))
        with torch.no_grad():
            y_hat = model(X)
        val_accuracies.append(100 * (y_hat.argmax(dim=1) == y).float().mean().item())
        val_loss = loss_fn(y_hat, y)
        losses[epoch, 1] = val_loss.item()

        print(
            f"Epoch {epoch + 1}/{epochs}, Train Loss: {losses[epoch, 0]:.4f}, Val Loss: {losses[epoch, 1]:.4f}"
        )

    return train_accuracies, val_accuracies, losses, model

# %%
train_accuracies, val_accuracies, losses, model = train_model(
    epochs=500, learning_rate=0.001
)
# Out:
# Epoch 1/500, Train Loss: 0.6670, Val Loss: 0.8320
# Epoch 2/500, Train Loss: 0.5914, Val Loss: 0.7362
# Epoch 3/500, Train Loss: 0.5704, Val Loss: 0.6438
# Epoch 4/500, Train Loss: 0.5598, Val Loss: 0.6687
# Epoch 5/500, Train Loss: 0.5583, Val Loss: 0.6549
# Epoch 6/500, Train Loss: 0.5550, Val Loss: 0.6313
# Epoch 7/500, Train Loss: 0.5561, Val Loss: 0.6469
# Epoch 8/500, Train Loss: 0.5544, Val Loss: 0.6889
# Epoch 9/500, Train Loss: 0.5545, Val Loss: 0.6543
# Epoch 10/500, Train Loss: 0.5539, Val Loss: 0.6208
# Epoch 11/500, Train Loss: 0.5523, Val Loss: 0.6379
# Epoch 12/500, Train Loss: 0.5545, Val Loss: 0.6887
# Epoch 13/500, Train Loss: 0.5539, Val Loss: 0.6236
# Epoch 14/500, Train Loss: 0.5532, Val Loss: 0.7156
# Epoch 15/500, Train Loss: 0.5540, Val Loss: 0.6261
# Epoch 16/500, Train Loss: 0.5506, Val Loss: 0.6527
# Epoch 17/500, Train Loss: 0.5535, Val Loss: 0.6945
# Epoch 18/500, Train Loss: 0.5543, Val Loss: 0.6356
# Epoch 19/500, Train Loss: 0.5529, Val Loss: 0.6449
# Epoch 20/500, Train Loss: 0.5525, Val Loss: 0.6491
# Epoch 21/500, Train Loss: 0.5506, Val Loss: 0.6594
# Epoch 22/500, Train Loss: 0.5518, Val Loss: 0.6471
# Epoch 23/500, Train Loss: 0.5498, Val Loss: 0.6161
# Epoch 24/500, Train Loss: 0.5509, Val Loss: 0.6234
# Epoch 25/500, Train Loss: 0.5498, Val Loss: 0.6450
# Epoch 26/500, Train Loss: 0.5508, Val Loss: 0.6282
# Epoch 27/500, Train Loss: 0.5505, Val Loss: 0.6174
# Epoch 28/500, Train Loss: 0.5487, Val Loss: 0.6520
# Epoch 29/500, Train Loss: 0.5483, Val Loss: 0.6219
# Epoch 30/500, Train Loss: 0.5506, Val Loss: 0.6923
# Epoch 468/500, Train Loss: 0.5308, Val Loss: 1.5679
# Epoch 469/500, Train Loss: 0.5312, Val Loss: 1.5632
# Epoch 470/500, Train Loss: 0.5314, Val Loss: 1.3485
# Epoch 471/500, Train Loss: 0.5324, Val Loss: 1.5382
# Epoch 472/500, Train Loss: 0.5318, Val Loss: 1.4741
# Epoch 473/500, Train Loss: 0.5301, Val Loss: 1.5368
# Epoch 474/500, Train Loss: 0.5319, Val Loss: 1.3334
# Epoch 475/500, Train Loss: 0.5318, Val Loss: 1.4907
# Epoch 476/500, Train Loss: 0.5310, Val Loss: 1.6501
# Epoch 477/500, Train Loss: 0.5309, Val Loss: 1.4346
# Epoch 478/500, Train Loss: 0.5308, Val Loss: 1.5687
# Epoch 479/500, Train Loss: 0.5308, Val Loss: 1.2950
# Epoch 480/500, Train Loss: 0.5320, Val Loss: 1.2876
# Epoch 481/500, Train Loss: 0.5302, Val Loss: 1.4196
# Epoch 482/500, Train Loss: 0.5314, Val Loss: 1.4791
# Epoch 483/500, Train Loss: 0.5304, Val Loss: 1.4453
# Epoch 484/500, Train Loss: 0.5299, Val Loss: 1.5305
# Epoch 485/500, Train Loss: 0.5299, Val Loss: 1.2449
# Epoch 486/500, Train Loss: 0.5301, Val Loss: 1.4887
# Epoch 487/500, Train Loss: 0.5305, Val Loss: 1.3909
# Epoch 488/500, Train Loss: 0.5311, Val Loss: 1.4497
# Epoch 489/500, Train Loss: 0.5301, Val Loss: 1.6206
# Epoch 490/500, Train Loss: 0.5310, Val Loss: 1.5702
# Epoch 491/500, Train Loss: 0.5317, Val Loss: 1.4515
# Epoch 492/500, Train Loss: 0.5305, Val Loss: 1.4838
# Epoch 493/500, Train Loss: 0.5296, Val Loss: 1.4230
# Epoch 494/500, Train Loss: 0.5301, Val Loss: 1.5543
# Epoch 495/500, Train Loss: 0.5291, Val Loss: 1.4844
# Epoch 496/500, Train Loss: 0.5315, Val Loss: 1.4533
# Epoch 497/500, Train Loss: 0.5317, Val Loss: 1.5165
# Epoch 498/500, Train Loss: 0.5297, Val Loss: 1.6629
# Epoch 499/500, Train Loss: 0.5306, Val Loss: 1.4073
# Epoch 500/500, Train Loss: 0.5319, Val Loss: 1.5256

# %%
# Calculate test accuracy
X_test, y_test = next(iter(test_loader))
with torch.no_grad():
    y_pred = model(X_test)
test_accuracy = 100 * (y_pred.argmax(dim=1) == y_test).float().mean().item()

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

ax[0].plot(losses, label="Train Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].set_title("Training Loss")
ax[0].legend(["Train Loss", "Validation Loss"])

ax[1].plot(train_accuracies, label="Train Accuracy")
ax[1].plot(val_accuracies, label="Validation Accuracy")
ax[1].axhline(
    test_accuracy,
    color="red",
    linestyle="--",
    label=f"Test Accuracy: {test_accuracy:.2f}%",
)
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Accuracy (%)")
ax[1].set_title(f"Training and Validation Accuracy: {val_accuracies[-1]:.2f}%")
ax[1].set_ylim(0, 100)
ax[1].legend()
